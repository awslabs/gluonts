# %%
import pandas as pd
import numpy as np
from gluonts.nursery.autogluon_tabular import LocalTabularPredictor
from gluonts.dataset.common import ListDataset
from gluonts.dataset.util import to_pandas
from gluonts.dataset.common import ListDataset
# Out:
# /Users/yixiaxia/.pyenv/versions/3.8.1/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Make or import a dataset with specific frequency.

# %%
dataset = ListDataset(
        [
            {
                "start": pd.Timestamp("1750-01-04 00:00:00", freq="W-SUN"),
                "target": np.array(
                    [1089.2, 1078.91, 1099.88, 35790.55, 34096.95, 34906.95],
                ),
            },
            {
                "start": pd.Timestamp("1750-01-04 00:00:00", freq="W-SUN"),
                "target": np.array(
                    [1099.2, 1098.91, 1069.88, 35990.55, 34076.95, 34766.95],
                ),
            },
            {
                "start": pd.Timestamp("1750-01-04 00:00:00", freq="W-SUN"),
                "target": np.array(
                    [1079.2, 1078.91, 1029.88, 35790.55, 34056.95, 34566.95],
                ),
            },
            {
                "start": pd.Timestamp("1750-01-04 00:00:00", freq="W-SUN"),
                "target": np.array(
                    [2059.2, 1057.91, 1019.88, 35590.55, 34036.95, 34366.95],
                ),
            },
            {
                "start": pd.Timestamp("1750-01-04 00:00:00", freq="W-SUN"),
                "target": np.array(
                    [1089.2, 1078.91, 1099.88, 35790.55, 34056.95, 34566.95],
                ),
            },
            {
                "start": pd.Timestamp("1750-01-04 00:00:00", freq="W-SUN"),
                "target": np.array(
                    [1049.2, 1057.91, 1049.88, 35590.55, 34036.95, 34366.95],
                ),
            },
        ],
        freq="W-SUN",
    )

# %% [markdown]
# Specify the prediction length and frequency.

# %%
prediction_length = 2
freq = "W-SUN"

# %% [markdown]
# Create a predictor. LocalTabularPredictor enables you to train a TabularPredictor for each time series by a Localizer. If LocalTabularPredictor is not uses, all of the time series in a dataset will be stacked together and trained into a general model.
# use_lag: specify if lagged values are needed
# lags: if use_lag is True, then specify a list of lagged values. If lags is not set, the TabularPredictor will automatically generate a list for you.
# Also, you can add kwargs for the fit, such as output_directory, presets. Please refer the arguments of task.fit in autogluon: https://auto.gluon.ai/api/autogluon.task.html#autogluon.tabular.TabularPrediction.fit.
# Specially, output_directory specifies the place where the training models saved

# %%
predictor = LocalTabularPredictor(
    freq=freq, 
    prediction_length=prediction_length, 
    use_lag=True, 
    lags=[]
    )

# %% [markdown]
# The prediction generates an iterator of the forecast values.

# %%
forecasts_it = predictor.predict(dataset)
forecasts = list(forecasts_it)
print(forecasts)
# Out:
# training for time series 1 / 6
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20210201_145350/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210201_145350/
# AutoGluon Version:  0.0.15
# Train Data Rows:    6
# Train Data Columns: 23
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5709.62 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 17): ['year_idx', 'day_of_week', 'hour_of_day', 'holiday', 'lag6', 'lag7', 'lag8', 'lag12', 'lag51', 'lag52', 'lag53', 'lag103', 'lag104', 'lag105', 'lag155', 'lag156', 'lag157']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	0.1s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'mean_absolute_error'
# Excluded Model Types: ['KNN', 'XT', 'RF']
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting model: LightGBMRegressor_STACKER_l0 ...
# 	-19178.3895	 = Validation mean_absolute_error score
# 	0.5s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMRegressorXT_STACKER_l0 ...
# 	-19178.3895	 = Validation mean_absolute_error score
# 	0.49s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatboostRegressor_STACKER_l0 ...
# 	-7023.4066	 = Validation mean_absolute_error score
# 	1.97s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetRegressor_STACKER_l0 ...
# 	-3342.6817	 = Validation mean_absolute_error score
# 	17.77s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMRegressorCustom_STACKER_l0 ...
# 	-19186.8573	 = Validation mean_absolute_error score
# 	0.48s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	-3342.6817	 = Validation mean_absolute_error score
# 	0.19s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 21.76s ...
# Fitting model: NeuralNetRegressor_FULL_STACKER_l0 ...
# 	2.14s	 = Training runtime
# Deleting model LightGBMRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145350/models/LightGBMRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorXT_STACKER_l0. All files under AutogluonModels/ag-20210201_145350/models/LightGBMRegressorXT_STACKER_l0/ will be removed.
# Deleting model CatboostRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145350/models/CatboostRegressor_STACKER_l0/ will be removed.
# Deleting model NeuralNetRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145350/models/NeuralNetRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorCustom_STACKER_l0. All files under AutogluonModels/ag-20210201_145350/models/LightGBMRegressorCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under AutogluonModels/ag-20210201_145350/models/weighted_ensemble_k0_l1/ will be removed.
# predicting for time series 1 / 6
# training for time series 2 / 6
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20210201_145414/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210201_145414/
# AutoGluon Version:  0.0.15
# Train Data Rows:    6
# Train Data Columns: 23
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5861.28 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 17): ['year_idx', 'day_of_week', 'hour_of_day', 'holiday', 'lag6', 'lag7', 'lag8', 'lag12', 'lag51', 'lag52', 'lag53', 'lag103', 'lag104', 'lag105', 'lag155', 'lag156', 'lag157']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	0.1s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'mean_absolute_error'
# Excluded Model Types: ['KNN', 'XT', 'RF']
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting model: LightGBMRegressor_STACKER_l0 ...
# 	-19190.0562	 = Validation mean_absolute_error score
# 	0.54s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMRegressorXT_STACKER_l0 ...
# 	-19190.0562	 = Validation mean_absolute_error score
# 	0.53s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatboostRegressor_STACKER_l0 ...
# 	-8440.971	 = Validation mean_absolute_error score
# 	7.09s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetRegressor_STACKER_l0 ...
# 	-6192.3943	 = Validation mean_absolute_error score
# 	16.5s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMRegressorCustom_STACKER_l0 ...
# 	-19199.6242	 = Validation mean_absolute_error score
# 	0.52s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	-6192.3943	 = Validation mean_absolute_error score
# 	0.2s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 25.71s ...
# Fitting model: NeuralNetRegressor_FULL_STACKER_l0 ...
# 	2.23s	 = Training runtime
# Deleting model LightGBMRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145414/models/LightGBMRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorXT_STACKER_l0. All files under AutogluonModels/ag-20210201_145414/models/LightGBMRegressorXT_STACKER_l0/ will be removed.
# Deleting model CatboostRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145414/models/CatboostRegressor_STACKER_l0/ will be removed.
# Deleting model NeuralNetRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145414/models/NeuralNetRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorCustom_STACKER_l0. All files under AutogluonModels/ag-20210201_145414/models/LightGBMRegressorCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under AutogluonModels/ag-20210201_145414/models/weighted_ensemble_k0_l1/ will be removed.
# predicting for time series 2 / 6
# training for time series 3 / 6
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20210201_145442/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210201_145442/
# AutoGluon Version:  0.0.15
# Train Data Rows:    6
# Train Data Columns: 23
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6070.38 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 17): ['year_idx', 'day_of_week', 'hour_of_day', 'holiday', 'lag6', 'lag7', 'lag8', 'lag12', 'lag51', 'lag52', 'lag53', 'lag103', 'lag104', 'lag105', 'lag155', 'lag156', 'lag157']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	0.1s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'mean_absolute_error'
# Excluded Model Types: ['KNN', 'XT', 'RF']
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting model: LightGBMRegressor_STACKER_l0 ...
# 	-19127.3895	 = Validation mean_absolute_error score
# 	0.71s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMRegressorXT_STACKER_l0 ...
# 	-19127.3895	 = Validation mean_absolute_error score
# 	0.6s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatboostRegressor_STACKER_l0 ...
# 	-8491.6008	 = Validation mean_absolute_error score
# 	5.98s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetRegressor_STACKER_l0 ...
# 	-4040.389	 = Validation mean_absolute_error score
# 	17.91s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMRegressorCustom_STACKER_l0 ...
# 	-19136.0575	 = Validation mean_absolute_error score
# 	0.55s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	-4040.389	 = Validation mean_absolute_error score
# 	0.21s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 26.31s ...
# Fitting model: NeuralNetRegressor_FULL_STACKER_l0 ...
# 	2.64s	 = Training runtime
# Deleting model LightGBMRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145442/models/LightGBMRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorXT_STACKER_l0. All files under AutogluonModels/ag-20210201_145442/models/LightGBMRegressorXT_STACKER_l0/ will be removed.
# Deleting model CatboostRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145442/models/CatboostRegressor_STACKER_l0/ will be removed.
# Deleting model NeuralNetRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145442/models/NeuralNetRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorCustom_STACKER_l0. All files under AutogluonModels/ag-20210201_145442/models/LightGBMRegressorCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under AutogluonModels/ag-20210201_145442/models/weighted_ensemble_k0_l1/ will be removed.
# predicting for time series 3 / 6
# training for time series 4 / 6
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20210201_145511/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210201_145511/
# AutoGluon Version:  0.0.15
# Train Data Rows:    6
# Train Data Columns: 23
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5857.38 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 17): ['year_idx', 'day_of_week', 'hour_of_day', 'holiday', 'lag6', 'lag7', 'lag8', 'lag12', 'lag51', 'lag52', 'lag53', 'lag103', 'lag104', 'lag105', 'lag155', 'lag156', 'lag157']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	0.0s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'mean_absolute_error'
# Excluded Model Types: ['KNN', 'XT', 'RF']
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting model: LightGBMRegressor_STACKER_l0 ...
# 	-18859.9226	 = Validation mean_absolute_error score
# 	0.51s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMRegressorXT_STACKER_l0 ...
# 	-18859.9226	 = Validation mean_absolute_error score
# 	0.45s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatboostRegressor_STACKER_l0 ...
# 	-8284.6285	 = Validation mean_absolute_error score
# 	5.89s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetRegressor_STACKER_l0 ...
# 	-5226.9762	 = Validation mean_absolute_error score
# 	16.31s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMRegressorCustom_STACKER_l0 ...
# 	-18867.6908	 = Validation mean_absolute_error score
# 	0.6s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	-5226.9762	 = Validation mean_absolute_error score
# 	0.21s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 24.3s ...
# Fitting model: NeuralNetRegressor_FULL_STACKER_l0 ...
# 	2.33s	 = Training runtime
# Deleting model LightGBMRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145511/models/LightGBMRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorXT_STACKER_l0. All files under AutogluonModels/ag-20210201_145511/models/LightGBMRegressorXT_STACKER_l0/ will be removed.
# Deleting model CatboostRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145511/models/CatboostRegressor_STACKER_l0/ will be removed.
# Deleting model NeuralNetRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145511/models/NeuralNetRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorCustom_STACKER_l0. All files under AutogluonModels/ag-20210201_145511/models/LightGBMRegressorCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under AutogluonModels/ag-20210201_145511/models/weighted_ensemble_k0_l1/ will be removed.
# predicting for time series 4 / 6
# training for time series 5 / 6
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20210201_145538/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210201_145538/
# AutoGluon Version:  0.0.15
# Train Data Rows:    6
# Train Data Columns: 23
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5900.34 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 17): ['year_idx', 'day_of_week', 'hour_of_day', 'holiday', 'lag6', 'lag7', 'lag8', 'lag12', 'lag51', 'lag52', 'lag53', 'lag103', 'lag104', 'lag105', 'lag155', 'lag156', 'lag157']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	0.1s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'mean_absolute_error'
# Excluded Model Types: ['KNN', 'XT', 'RF']
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting model: LightGBMRegressor_STACKER_l0 ...
# 	-19113.7229	 = Validation mean_absolute_error score
# 	0.58s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMRegressorXT_STACKER_l0 ...
# 	-19113.7229	 = Validation mean_absolute_error score
# 	0.49s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatboostRegressor_STACKER_l0 ...
# 	-7025.9637	 = Validation mean_absolute_error score
# 	1.9s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetRegressor_STACKER_l0 ...
# 	-5602.0195	 = Validation mean_absolute_error score
# 	15.68s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMRegressorCustom_STACKER_l0 ...
# 	-19122.3908	 = Validation mean_absolute_error score
# 	0.64s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	-5602.0195	 = Validation mean_absolute_error score
# 	0.21s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 19.82s ...
# Fitting model: NeuralNetRegressor_FULL_STACKER_l0 ...
# 	2.4s	 = Training runtime
# Deleting model LightGBMRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145538/models/LightGBMRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorXT_STACKER_l0. All files under AutogluonModels/ag-20210201_145538/models/LightGBMRegressorXT_STACKER_l0/ will be removed.
# Deleting model CatboostRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145538/models/CatboostRegressor_STACKER_l0/ will be removed.
# Deleting model NeuralNetRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145538/models/NeuralNetRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorCustom_STACKER_l0. All files under AutogluonModels/ag-20210201_145538/models/LightGBMRegressorCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under AutogluonModels/ag-20210201_145538/models/weighted_ensemble_k0_l1/ will be removed.
# predicting for time series 5 / 6
# training for time series 6 / 6
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20210201_145600/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210201_145600/
# AutoGluon Version:  0.0.15
# Train Data Rows:    6
# Train Data Columns: 23
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5886.24 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 17): ['year_idx', 'day_of_week', 'hour_of_day', 'holiday', 'lag6', 'lag7', 'lag8', 'lag12', 'lag51', 'lag52', 'lag53', 'lag103', 'lag104', 'lag105', 'lag155', 'lag156', 'lag157']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['month_of_year']
# 		('float', [])    : 5 | ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']
# 	0.1s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.06s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'mean_absolute_error'
# Excluded Model Types: ['KNN', 'XT', 'RF']
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting model: LightGBMRegressor_STACKER_l0 ...
# 	-19056.9226	 = Validation mean_absolute_error score
# 	0.54s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMRegressorXT_STACKER_l0 ...
# 	-19056.9226	 = Validation mean_absolute_error score
# 	0.5s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatboostRegressor_STACKER_l0 ...
# 	-9515.9457	 = Validation mean_absolute_error score
# 	1.54s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetRegressor_STACKER_l0 ...
# 	-4777.3617	 = Validation mean_absolute_error score
# 	15.68s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMRegressorCustom_STACKER_l0 ...
# 	-19064.6905	 = Validation mean_absolute_error score
# 	0.56s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	-4777.3617	 = Validation mean_absolute_error score
# 	0.22s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 19.36s ...
# Fitting model: NeuralNetRegressor_FULL_STACKER_l0 ...
# 	2.24s	 = Training runtime
# Deleting model LightGBMRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145600/models/LightGBMRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorXT_STACKER_l0. All files under AutogluonModels/ag-20210201_145600/models/LightGBMRegressorXT_STACKER_l0/ will be removed.
# Deleting model CatboostRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145600/models/CatboostRegressor_STACKER_l0/ will be removed.
# Deleting model NeuralNetRegressor_STACKER_l0. All files under AutogluonModels/ag-20210201_145600/models/NeuralNetRegressor_STACKER_l0/ will be removed.
# Deleting model LightGBMRegressorCustom_STACKER_l0. All files under AutogluonModels/ag-20210201_145600/models/LightGBMRegressorCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under AutogluonModels/ag-20210201_145600/models/weighted_ensemble_k0_l1/ will be removed.
# predicting for time series 6 / 6
# [gluonts.model.forecast.SampleForecast(freq="W-SUN", info=None, item_id=None, samples=numpy.array([[36636.95703125, 36636.95703125]], numpy.dtype("float64")), start_date=pandas.Timestamp("1750-02-15 00:00:00", freq="W-SUN")), gluonts.model.forecast.SampleForecast(freq="W-SUN", info=None, item_id=None, samples=numpy.array([[36837.3984375, 36837.3984375]], numpy.dtype("float64")), start_date=pandas.Timestamp("1750-02-15 00:00:00", freq="W-SUN")), gluonts.model.forecast.SampleForecast(freq="W-SUN", info=None, item_id=None, samples=numpy.array([[36634.49609375, 36634.49609375]], numpy.dtype("float64")), start_date=pandas.Timestamp("1750-02-15 00:00:00", freq="W-SUN")), gluonts.model.forecast.SampleForecast(freq="W-SUN", info=None, item_id=None, samples=numpy.array([[24064.591796875, 36423.20703125]], numpy.dtype("float64")), start_date=pandas.Timestamp("1750-02-15 00:00:00", freq="W-SUN")), gluonts.model.forecast.SampleForecast(freq="W-SUN", info=None, item_id=None, samples=numpy.array([[36633.83203125, 36633.83203125]], numpy.dtype("float64")), start_date=pandas.Timestamp("1750-02-15 00:00:00", freq="W-SUN")), gluonts.model.forecast.SampleForecast(freq="W-SUN", info=None, item_id=None, samples=numpy.array([[24534.080078125, 36431.1953125]], numpy.dtype("float64")), start_date=pandas.Timestamp("1750-02-15 00:00:00", freq="W-SUN"))]
